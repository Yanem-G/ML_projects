# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split,KFold
import tensorflow as tf
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("train.csv")
test = pd.read_csv('test.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df['LotArea'].isnull().sum()
# Out:
# 0

# %%
df=df.drop(["Neighborhood","Exterior1st","Exterior2nd"],axis=1)

test=test.drop(["Neighborhood","Exterior1st","Exterior2nd"],axis=1)

# %%
df['LotFrontage']=df['LotFrontage'].fillna(0)
df['LotFrontage']=df['LotFrontage'].astype('int64')
df['SalePrice']=df['SalePrice'].astype(int)
df['MasVnrArea']=df['MasVnrArea'].fillna(0)
df['GarageYrBlt']=df['GarageYrBlt'].fillna(0)
df["PoolQC"]=df["PoolQC"].fillna('NoPool')
df["Alley"]=df["Alley"].fillna('NoAlley')

df["BsmtQual"]=df["BsmtQual"].fillna('NoBsmt')
df["BsmtCond"]=df["BsmtCond"].fillna('NoBsmt')
df["BsmtExposure"]=df["BsmtExposure"].fillna('NoBsmt')
df["BsmtFinType1"]=df["BsmtFinType1"].fillna('NoBsmt')
df["BsmtFinType2"]=df["BsmtFinType2"].fillna('NoBsmt')
df["HeatingQC"]=df["HeatingQC"].fillna('NoHeating')
df["FireplaceQu"]=df["FireplaceQu"].fillna('NoFireplace')
df["GarageFinish"]=df["GarageFinish"].fillna('NoGarage')
df["GarageQual"]=df["GarageQual"].fillna('NoGarage')
df["GarageCond"]=df["GarageCond"].fillna('NoGarage')
df["Fence"]=df["Fence"].fillna('NoFence')

# %%
test['LotFrontage']=test['LotFrontage'].fillna(0)
test['LotFrontage']=test['LotFrontage'].astype('int64')
test['MasVnrArea']=test['MasVnrArea'].fillna(0)
test['GarageYrBlt']=test['GarageYrBlt'].fillna(0)
test["PoolQC"]=test["PoolQC"].fillna('NoPool')
test["Alley"]=test["Alley"].fillna('NoAlley')

test["BsmtQual"]=test["BsmtQual"].fillna('NoBsmt')
test["BsmtCond"]=test["BsmtCond"].fillna('NoBsmt')
test["BsmtExposure"]=test["BsmtExposure"].fillna('NoBsmt')
test["BsmtFinType1"]=test["BsmtFinType1"].fillna('NoBsmt')
test["BsmtFinType2"]=test["BsmtFinType2"].fillna('NoBsmt')
test["HeatingQC"]=test["HeatingQC"].fillna('NoHeating')
test["FireplaceQu"]=test["FireplaceQu"].fillna('NoFireplace')
test["GarageFinish"]=test["GarageFinish"].fillna('NoGarage')
test["GarageQual"]=test["GarageQual"].fillna('NoGarage')
test["GarageCond"]=test["GarageCond"].fillna('NoGarage')
test["Fence"]=test["Fence"].fillna('NoFence')

# %%
df=pd.get_dummies(df,columns=['MSZoning'],dtype=int)
df=pd.get_dummies(df,columns=['LotShape'],dtype=int)
df=pd.get_dummies(df,columns=['LandContour'],dtype=int)
df=pd.get_dummies(df,columns=['Utilities'],dtype=int)
df=pd.get_dummies(df,columns=['LotConfig'],dtype=int)
df=pd.get_dummies(df,columns=['LandSlope'],dtype=int)
df=pd.get_dummies(df,columns=['Condition1'],dtype=int)
df=pd.get_dummies(df,columns=['Condition2'],dtype=int)
df=pd.get_dummies(df,columns=['BldgType'],dtype=int)
df=pd.get_dummies(df,columns=['HouseStyle'],dtype=int)
df=pd.get_dummies(df,columns=['Electrical'],dtype=int)
df=pd.get_dummies(df,columns=['Functional'],dtype=int)
df=pd.get_dummies(df,columns=['GarageType'],dtype=int)
df=pd.get_dummies(df,columns=['MiscFeature'],dtype=int)
df=pd.get_dummies(df,columns=['PavedDrive'],dtype=int)
df=pd.get_dummies(df,columns=["PoolQC"],dtype=int)
df=pd.get_dummies(df,columns=["KitchenQual"],dtype=int)
df=pd.get_dummies(df,columns=["MasVnrType"],dtype=int)
df=pd.get_dummies(df,columns=["Street"],dtype=int)
df=pd.get_dummies(df,columns=["Alley"],dtype=int)
df=pd.get_dummies(df,columns=["SaleType"],dtype=int)
df=pd.get_dummies(df,columns=["SaleCondition"],dtype=int)
df=pd.get_dummies(df,columns=["RoofStyle"],dtype=int)
df=pd.get_dummies(df,columns=["RoofMatl"],dtype=int)
df=pd.get_dummies(df,columns=["ExterCond"],dtype=int)
df=pd.get_dummies(df,columns=["ExterQual"],dtype=int)
df=pd.get_dummies(df,columns=["Foundation"],dtype=int)
df=pd.get_dummies(df,columns=["BsmtQual"],dtype=int)
df=pd.get_dummies(df,columns=["BsmtCond"],dtype=int)
df=pd.get_dummies(df,columns=["BsmtFinType1"],dtype=int)
df=pd.get_dummies(df,columns=["BsmtFinType2"],dtype=int)
df=pd.get_dummies(df,columns=["BsmtExposure"],dtype=int)
df=pd.get_dummies(df,columns=["Heating"],dtype=int)
df=pd.get_dummies(df,columns=["HeatingQC"],dtype=int)
df=pd.get_dummies(df,columns=["FireplaceQu"],dtype=int)
df=pd.get_dummies(df,columns=["GarageFinish"],dtype=int)
df=pd.get_dummies(df,columns=["GarageCond"],dtype=int)
df=pd.get_dummies(df,columns=["GarageQual"],dtype=int)
df=pd.get_dummies(df,columns=["Fence"],dtype=int)

# %%
test=pd.get_dummies(test,columns=['LotShape'],dtype=int)
test=pd.get_dummies(test,columns=['MSZoning'],dtype=int)
test=pd.get_dummies(test,columns=['LandContour'],dtype=int)
test=pd.get_dummies(test,columns=['Utilities'],dtype=int)
test=pd.get_dummies(test,columns=['LotConfig'],dtype=int)
test=pd.get_dummies(test,columns=['LandSlope'],dtype=int)
test=pd.get_dummies(test,columns=['Condition1'],dtype=int)
test=pd.get_dummies(test,columns=['Condition2'],dtype=int)
test=pd.get_dummies(test,columns=['BldgType'],dtype=int)
test=pd.get_dummies(test,columns=['HouseStyle'],dtype=int)
test=pd.get_dummies(test,columns=['Electrical'],dtype=int)
test=pd.get_dummies(test,columns=['Functional'],dtype=int)
test=pd.get_dummies(test,columns=['GarageType'],dtype=int)
test=pd.get_dummies(test,columns=['MiscFeature'],dtype=int)
test=pd.get_dummies(test,columns=['PavedDrive'],dtype=int)
test=pd.get_dummies(test,columns=["PoolQC"],dtype=int)
test=pd.get_dummies(test,columns=["KitchenQual"],dtype=int)
test=pd.get_dummies(test,columns=["MasVnrType"],dtype=int)
test=pd.get_dummies(test,columns=["Street"],dtype=int)
test=pd.get_dummies(test,columns=["Alley"],dtype=int)
test=pd.get_dummies(test,columns=["SaleType"],dtype=int)
test=pd.get_dummies(test,columns=["SaleCondition"],dtype=int)
test=pd.get_dummies(test,columns=["RoofStyle"],dtype=int)
test=pd.get_dummies(test,columns=["RoofMatl"],dtype=int)
test=pd.get_dummies(test,columns=["ExterCond"],dtype=int)
test=pd.get_dummies(test,columns=["ExterQual"],dtype=int)
test=pd.get_dummies(test,columns=["Foundation"],dtype=int)
test=pd.get_dummies(test,columns=["BsmtQual"],dtype=int)
test=pd.get_dummies(test,columns=["BsmtCond"],dtype=int)
test=pd.get_dummies(test,columns=["BsmtFinType1"],dtype=int)
test=pd.get_dummies(test,columns=["BsmtFinType2"],dtype=int)
test=pd.get_dummies(test,columns=["BsmtExposure"],dtype=int)
test=pd.get_dummies(test,columns=["Heating"],dtype=int)
test=pd.get_dummies(test,columns=["HeatingQC"],dtype=int)
test=pd.get_dummies(test,columns=["FireplaceQu"],dtype=int)
test=pd.get_dummies(test,columns=["GarageFinish"],dtype=int)
test=pd.get_dummies(test,columns=["GarageCond"],dtype=int)
test=pd.get_dummies(test,columns=["GarageQual"],dtype=int)
test=pd.get_dummies(test,columns=["Fence"],dtype=int)

# %%
mapping2={'Y' : 1 ,'N' : 0}
df['CentralAir']=df['CentralAir'].map(mapping2).astype('int64')
test['CentralAir']=test['CentralAir'].map(mapping2).astype('int64')

# %%
df = df.apply(lambda x: x.astype('int64') if pd.api.types.is_integer_dtype(x) else x)
test = test.apply(lambda x: x.astype('int64') if pd.api.types.is_integer_dtype(x) else x)

# %%
df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60           65     8450            7            5       2003
# 1   2          20           80     9600            6            8       1976
# 2   3          60           68    11250            7            5       2001
# 3   4          70           60     9550            7            5       1915
# 4   5          60           84    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageQual_Fa  GarageQual_Gd  \
# 0          2003       196.0         706  ...              0              0
# 1          1976         0.0         978  ...              0              0
# 2          2002       162.0         486  ...              0              0
# 3          1970         0.0         216  ...              0              0
# 4          2000       350.0         655  ...              0              0
#
# ...

# %%
df.dtypes
# Out:
# Id               int64
# MSSubClass       int64
# LotFrontage      int64
# LotArea          int64
# OverallQual      int64
#                  ...
# Fence_GdPrv      int64
# Fence_GdWo       int64
# Fence_MnPrv      int64
# Fence_MnWw       int64
# Fence_NoFence    int64
# Length: 244, dtype: object

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
#                 ..
# Fence_GdPrv      0
# Fence_GdWo       0
# Fence_MnPrv      0
# Fence_MnWw       0
# Fence_NoFence    0
# Length: 244, dtype: int64

# %%
for col in df.columns:
    if not pd.api.types.is_numeric_dtype(df[col]):
        print(f"Non-numeric column: {col}")

# %%
X = df.drop(['SalePrice'],axis=1)
y = df['SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
non_numeric_data = X_train.loc[:, X_train.apply(lambda x: pd.to_numeric(x, errors='coerce').isna().any())] 
print(non_numeric_data)
# Out:
# Empty DataFrame
# Columns: []
# Index: [469, 1195, 48, 198, 1356, 4, 1264, 264, 1009, 299, 1034, 769, 630, 1331, 756, 101, 1301, 82, 988, 904, 1316, 174, 180, 368, 1304, 553, 268, 783, 808, 1299, 389, 1160, 902, 153, 72, 901, 417, 772, 1081, 1246, 704, 1419, 193, 141, 27, 30, 287, 151, 516, 856, 310, 1231, 1155, 777, 701, 1428, 805, 1375, 869, 43, 924, 881, 707, 1453, 845, 984, 267, 413, 1142, 1082, 540, 525, 1219, 134, 763, 1253, 96, 1226, 575, 627, 1019, 835, 468, 405, 532, 896, 969, 909, 35, 508, 271, 580, 52, 559, 158, 1459, 415, 980, 1258, 1111, ...]
#
# [1168 rows x 0 columns]

# %% [markdown]
# to check non numeric data

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
assert len(X_train) == len(y_train)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

for train_idx, val_idx in kf.split(X_train):
    print(len(train_idx), len(val_idx))
    assert len(train_idx) + len(val_idx) == len(X_train)

    X_cv_train, X_cv_test = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_cv_train, y_cv_test = y_train.iloc[train_idx], y_train.iloc[val_idx]

    print(X_cv_train.shape, y_cv_train.shape)
    assert X_cv_train.shape[0] == y_cv_train.shape[0]
# Out:
# X_train shape: (1168, 243)
# y_train shape: (1168,)
# 934 234
# (934, 243) (934,)
# 934 234
# (934, 243) (934,)
# 934 234
# (934, 243) (934,)
# 935 233
# (935, 243) (935,)
# 935 233
# (935, 243) (935,)

# %% [markdown]
# best verage Mean Squared Error (MSE):2001094460.6523342
# best hyperparameters is {'num_of_layers': 4, 'num_of_units': [256, 512, 512, 512]}

# %%
model = RandomForestRegressor()
param_dist = {'n_estimators': randint(50,1000),
              'max_depth': randint(1,40),
              'min_samples_split': randint(2, 10),
              'min_samples_leaf': randint(1, 5)}
random_search=RandomizedSearchCV(model,param_distributions=param_dist,scoring='neg_mean_squared_error',n_iter=50,cv=5,random_state=42,n_jobs=-1)
random_search.fit(X_train,y_train)
best_model=random_search.best_estimator_
#It will score them based on negative MSE (since lower MSE is better, but sklearn's scorer needs to maximize something)
#Added min_samples_split and min_samples_leaf — both control overfitting and improve tree generalization.

# %%
prediction = best_model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, prediction)
r2 = r2_score(y_test, prediction)

print(f'Mean Squared Error (MSE): {mse}')
print(f'R^2 Score: {r2}')
rmse = np.sqrt(mse)
print(f"RMSE: {rmse}")
# Out:
# Mean Squared Error (MSE): 486035892.7103252
# R^2 Score: 0.9024920170012326
# RMSE: 22046.22173322053

# %% [markdown]
# Mean Squared Error (MSE): 672533587.4205245
# R^2 Score: 0.9099445343017578
# RMSE: 25933.252542257873

# %%
test = test.reindex(columns=X_train.columns, fill_value=0)

# %% [markdown]
# 1797406887.930039

# %%
result = best_model.predict(test)
test['SalePrice'] = result

# %%
submission = test[['Id', 'SalePrice']]
submission.to_csv("final_submission_house_pre_random_forest.csv", index=False)
